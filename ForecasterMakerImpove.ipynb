# %%
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
import pickle
import os
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from statistics import mean 
import warnings
import time
warnings.filterwarnings('ignore')
files = os.listdir('trends5days')
files.pop(0)
mog = []
for x in files:
    df = pd.read_csv('trends5days/'+ x)
    mog.append(df)
print(mog[0])
print(mog[1])
def predict(date):
    s = time.time()
    dicct = {}
    ig=0
    for x in range(len(mog)):
        #loading dataframe for ml 
        df = pd.DataFrame(mog[x])
        
        df1 = df[['Open0', 'High0', 'Low0', 'Close0', 'Adjusted_close0', 'Volume0', 'rsi0', 'ema0', 'Open1', 'High1', 'Low1', 'Close1', 'Adjusted_close1', 'Volume1', 'rsi1', 'ema1', 'Open2', 'High2', 'Low2', 'Close2', 'Adjusted_close2', 'Volume2', 'rsi2', 'ema2', 'Open3', 'High3', 'Low3', 'Close3', 'Adjusted_close3', 'Volume3', 'rsi3', 'ema3', 'Open4', 'High4', 'Low4', 'Close4', 'Adjusted_close4', 'Volume4', 'rsi4', 'ema4', 'Open5', 'High5', 'Low5', 'Close5', 'Adjusted_close5', 'Volume5', 'rsi5', 'ema5', 'Open6', 'High6', 'Low6', 'Close6', 'Adjusted_close6', 'Volume6', 'rsi6', 'ema6', 'Open7', 'High7', 'Low7', 'Close7', 'Adjusted_close7', 'Volume7', 'rsi7', 'ema7', 'Open8', 'High8', 'Low8', 'Close8', 'Adjusted_close8', 'Volume8', 'rsi8', 'ema8', 'Open9', 'High9', 'Low9', 'Close9', 'Adjusted_close9', 'Volume9', 'rsi9', 'ema9', 'Open10', 'High10', 'Low10', 'Close10', 'Adjusted_close10', 'Volume10', 'rsi10', 'ema10', 'Open11', 'High11', 'Low11', 'Close11', 'Adjusted_close11', 'Volume11', 'rsi11', 'ema11', 'Open12', 'High12', 'Low12', 'Close12', 'Adjusted_close12', 'Volume12', 'rsi12', 'ema12', 'Open13', 'High13', 'Low13', 'Close13', 'Adjusted_close13', 'Volume13', 'rsi13', 'ema13', 'Open14', 'High14', 'Low14', 'Close14', 'Adjusted_close14', 'Volume14', 'rsi14', 'ema14', 'Open15', 'High15', 'Low15', 'Close15', 'Adjusted_close15', 'Volume15', 'rsi15', 'ema15', 'Open16', 'High16', 'Low16', 'Close16', 'Adjusted_close16', 'Volume16', 'rsi16', 'ema16', 'Open17', 'High17', 'Low17', 'Close17', 'Adjusted_close17', 'Volume17', 'rsi17', 'ema17', 'Open18', 'High18', 'Low18', 'Close18', 'Adjusted_close18', 'Volume18', 'rsi18', 'ema18', 'Open19', 'High19', 'Low19', 'Close19', 'Adjusted_close19', 'Volume19', 'rsi19', 'ema19']]
        #number = files.index(x)
        loaded_model = pickle.load(open('trends5daysModelCorrect/'+files[x][:-4] +'.sav', 'rb'))
        #loading dataframe with dates
        dates = df['Date'].to_numpy()

        if date not in dates:
            print('FuCK')
            return 0
        pos = np.where(dates == date)          
        predic = df1.loc[[pos[0][0]]].to_numpy()
        vb = loaded_model.predict(predic)
        if vb == 1:
            bv = loaded_model.predict_proba(predic)
            dicct[files[x]] = bv[0][1]    
    e = time.time()
    print("Modin Concat Time = {}".format(e-s))

    return dicct
dictt = {}
dictshort = {}
df_3 = pd.read_csv('trends5days/ADBETRENDS.csv')
df_3.dropna(inplace=True)
fgg = df_3['Date'].to_list()
gg = fgg[3000:]
print('LE')
for x in range(0,len(gg),5):
    prob_list = predict(gg[x])
    print('DONE: ',x/5)
    if prob_list != 0:
        my_keys = sorted(prob_list, key=prob_list.get, reverse=True)[:10]
        short_keys = sorted(prob_list, key=prob_list.get)[:5]
        dictt[gg[x]] = my_keys
        dictshort[gg[x]] = short_keys

        
dfgh = pd.DataFrame.from_dict(dictt, orient='index',
                       columns=['date', 's1', 's2', 's3','s4','s5','s6','s7','s8','s9'])        
dfgh.to_csv('kol12345Correct')
# Out:
#       Unnamed: 0        Date     Open     High      Low    Close  \
# 0              0  2004-01-02  11.8106  11.9536  11.6086  11.6708
# 1              1  2004-01-05  11.7795  12.0841  11.7330  12.0531
# 2              2  2004-01-06  12.0904  12.2582  11.8448  11.9629
# 3              3  2004-01-07  11.8728  11.9101  11.7330  11.8728
# 4              4  2004-01-08  12.1215  12.1836  11.9039  12.0157
# ...          ...         ...      ...      ...      ...      ...
# 4333        4333  2021-03-22  31.2300  31.4200  30.0800  30.4300
# 4334        4334  2021-03-23  28.3900  29.2500  27.1100  27.4200
# 4335        4335  2021-03-24  29.7200  30.4800  28.5900  28.7600
# 4336        4336  2021-03-25  28.0300  29.7650  27.5500  29.6600
# 4337        4337  2021-03-26  30.4100  32.8000  30.1500  32.7800
#
#       Adjusted_close      Volume        rsi      ema  ...     rsi18     ema18  \
# 0                0.0  1722766.67        NaN      NaN  ...       NaN       NaN
# 1                0.0  2812133.33        NaN      NaN  ...       NaN       NaN
# 2                0.0  2140400.00        NaN      NaN  ...       NaN       NaN
# 3                0.0  2317899.67        NaN      NaN  ...       NaN       NaN
# 4                0.0  2637766.33        NaN      NaN  ...       NaN       NaN
# ...              ...         ...        ...      ...  ...       ...       ...
# 4333            54.0  3552300.00  59.036455  24.5972  ...  0.709853  0.403779
# 4334            54.0  8474600.00  48.121604  24.6458  ...  0.591548  0.404879
# 4335            54.0  9127500.00  52.345600  24.7298  ...  0.529578  0.406007
# 4336            54.0  6403000.00  54.995995  24.8214  ...  0.584114  0.407552
# 4337            54.0  9567200.00  62.733824  24.9882  ...  0.632454  0.409946
#
#         Open19    High19     Low19   Close19  Adjusted_close19  Volume19  \
# 0          NaN       NaN       NaN       NaN               NaN       NaN
# 1          NaN       NaN       NaN       NaN               NaN       NaN
# 2          NaN       NaN       NaN       NaN               NaN       NaN
# 3          NaN       NaN       NaN       NaN               NaN       NaN
# 4          NaN       NaN       NaN       NaN               NaN       NaN
# ...        ...       ...       ...       ...               ...       ...
# 4333  0.377501  0.385402  0.368960  0.397178              0.60  0.066320
# 4334  0.398545  0.421691  0.406019  0.436422              0.60  0.103367
# 4335  0.438936  0.430103  0.406105  0.408440              0.60  0.096745
# 4336  0.383271  0.383588  0.380853  0.391206              0.60  0.071355
# 4337  0.408219  0.406680  0.411190  0.415776              0.54  0.060703
#
#          rsi19     ema19
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ...        ...       ...
# 4333  0.631404  0.402490
# 4334  0.709853  0.403779
# 4335  0.591548  0.404879
# 4336  0.529578  0.406007
# 4337  0.584114  0.407552
#
# [4338 rows x 171 columns]
#       Unnamed: 0        Date   Open   High     Low   Close  Adjusted_close  \
# 0              0  2004-01-02  16.11  16.29  15.870  16.290             0.0
# 1              1  2004-01-05  16.63  16.64  15.971  16.560             0.0
# 2              2  2004-01-06  16.83  16.99  16.460  16.661             0.0
# 3              3  2004-01-07  16.95  16.95  16.650  16.870             0.0
# 4              4  2004-01-08  16.77  17.18  16.770  17.000             0.0
# ...          ...         ...    ...    ...     ...     ...             ...
# 4333        4333  2021-03-22  55.87  55.87  53.630  54.150            40.0
# 4334        4334  2021-03-23  53.53  54.31  51.570  51.990            40.0
# 4335        4335  2021-03-24  52.85  54.41  51.590  51.650            40.0
# 4336        4336  2021-03-25  51.27  53.10  50.800  52.680            40.0
# 4337        4337  2021-03-26  53.47  55.01  53.150  54.940            40.0
#
#         Volume        rsi      ema  ...     rsi18     ema18    Open19  \
# 0      11264.0        NaN      NaN  ...       NaN       NaN       NaN
# 1       6093.0        NaN      NaN  ...       NaN       NaN       NaN
# 2       7233.0        NaN      NaN  ...       NaN       NaN       NaN
# 3       2400.0        NaN      NaN  ...       NaN       NaN       NaN
# 4       9435.0        NaN      NaN  ...       NaN       NaN       NaN
# ...        ...        ...      ...  ...       ...       ...       ...
# 4333  520200.0  64.261547  47.3232  ...  0.806243  0.735962  0.822218
# 4334  609900.0  53.415051  47.5080  ...  0.639206  0.740213  0.844141
# 4335  439900.0  51.929251  47.6692  ...  0.606630  0.744215  0.867170
# 4336  460400.0  55.928660  47.8394  ...  0.664188  0.748190  0.810427
# 4337  612800.0  63.169353  48.0578  ...  0.660589  0.752413  0.831430
#
#         High19     Low19   Close19  Adjusted_close19  Volume19     rsi19  \
# 0          NaN       NaN       NaN               NaN       NaN       NaN
# 1          NaN       NaN       NaN               NaN       NaN       NaN
# 2          NaN       NaN       NaN               NaN       NaN       NaN
# 3          NaN       NaN       NaN               NaN       NaN       NaN
# 4          NaN       NaN       NaN               NaN       NaN       NaN
# ...        ...       ...       ...               ...       ...       ...
# 4333  0.823797  0.821455  0.834313              0.45  0.075184  0.768471
# 4334  0.846685  0.851983  0.855621              0.45  0.088616  0.806243
# 4335  0.852134  0.820715  0.816679              0.45  0.079857  0.639206
# 4336  0.809083  0.808504  0.807862              0.45  0.073389  0.606630
# 4337  0.819619  0.829781  0.833211              0.40  0.068633  0.664188
#
#          ema19
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 4333  0.730853
# 4334  0.735962
# 4335  0.740213
# 4336  0.744215
# 4337  0.748190
#
# [4338 rows x 171 columns]
# LE
# Modin Concat Time = 4.284319639205933
# DONE:  0.0
# Modin Concat Time = 3.9306869506835938
# DONE:  1.0
# Modin Concat Time = 3.891207218170166
# DONE:  2.0
# Modin Concat Time = 3.952460289001465
# DONE:  3.0
# Modin Concat Time = 3.974923610687256
# DONE:  4.0
# Modin Concat Time = 3.748797655105591
# DONE:  5.0
# FuCK
# DONE:  6.0
# Modin Concat Time = 3.7488276958465576
# DONE:  7.0
# Modin Concat Time = 3.818830966949463
# DONE:  8.0
# Modin Concat Time = 3.8037147521972656
# DONE:  9.0
# Modin Concat Time = 3.7676594257354736
# DONE:  10.0
# Modin Concat Time = 3.7452220916748047
# DONE:  11.0
# Modin Concat Time = 3.782078504562378
# DONE:  12.0
# Modin Concat Time = 3.781806468963623
# DONE:  13.0
# FuCK
# DONE:  14.0
# Modin Concat Time = 3.798412799835205
# DONE:  15.0
# Modin Concat Time = 3.7503223419189453
# DONE:  16.0
# Modin Concat Time = 3.73513126373291
# DONE:  17.0
# Modin Concat Time = 3.73582124710083
# DONE:  18.0
# Modin Concat Time = 3.7707154750823975
# DONE:  19.0
# Modin Concat Time = 3.7353103160858154
# DONE:  20.0
# Modin Concat Time = 4.487733364105225
# DONE:  21.0
# Modin Concat Time = 4.134260892868042
# DONE:  22.0
# Modin Concat Time = 3.909491539001465
# DONE:  23.0
# Modin Concat Time = 3.894836902618408
# DONE:  24.0
# Modin Concat Time = 3.88466477394104
# DONE:  25.0
# Modin Concat Time = 3.8990776538848877
# DONE:  26.0
# Modin Concat Time = 3.8830296993255615
# DONE:  27.0
# Modin Concat Time = 3.904799222946167
# DONE:  28.0
# Modin Concat Time = 3.9243531227111816
# DONE:  29.0
# Modin Concat Time = 3.9389090538024902
# DONE:  30.0
# Modin Concat Time = 3.9061710834503174
# DONE:  31.0
# Modin Concat Time = 3.858358860015869
# DONE:  32.0
# Modin Concat Time = 3.889369010925293
# DONE:  33.0
# Modin Concat Time = 3.869096279144287
# DONE:  34.0
# Modin Concat Time = 3.845576524734497
# DONE:  35.0
# Modin Concat Time = 3.8663723468780518
# DONE:  36.0
# Modin Concat Time = 3.8576462268829346
# DONE:  37.0
# Modin Concat Time = 3.8975720405578613
# DONE:  38.0
# FuCK
# DONE:  39.0
# Modin Concat Time = 3.8460118770599365
# DONE:  40.0
# Modin Concat Time = 3.857046127319336
# DONE:  41.0
# Modin Concat Time = 3.837346076965332
# DONE:  42.0
# Modin Concat Time = 3.945240020751953
# DONE:  43.0
# Modin Concat Time = 3.8422303199768066
# DONE:  44.0
# Modin Concat Time = 3.8298168182373047
# DONE:  45.0
# Modin Concat Time = 3.8679184913635254
# DONE:  46.0
# Modin Concat Time = 3.812889337539673
# DONE:  47.0
# Modin Concat Time = 3.896172046661377
# DONE:  48.0
# Modin Concat Time = 3.816678285598755
# DONE:  49.0
# Modin Concat Time = 3.8623464107513428
# DONE:  50.0
# Modin Concat Time = 3.8455052375793457
# DONE:  51.0
# Modin Concat Time = 3.8908231258392334
# DONE:  52.0
# Modin Concat Time = 3.806532621383667
# DONE:  53.0
# Modin Concat Time = 3.886652946472168
# DONE:  54.0
# Modin Concat Time = 3.871640682220459
# DONE:  55.0
# Modin Concat Time = 3.9193286895751953
# DONE:  56.0
# Modin Concat Time = 3.837275981903076
# DONE:  57.0
# Modin Concat Time = 3.8708484172821045
# DONE:  58.0
# Modin Concat Time = 3.8565163612365723
# DONE:  59.0
# Modin Concat Time = 3.923508644104004
# DONE:  60.0
# Modin Concat Time = 3.734762191772461
# DONE:  61.0
# Modin Concat Time = 3.6863536834716797
# DONE:  62.0
# Modin Concat Time = 3.7833871841430664
# DONE:  63.0
# Modin Concat Time = 3.705580472946167
# DONE:  64.0
# Modin Concat Time = 3.7039496898651123
# DONE:  65.0
# Modin Concat Time = 3.7286770343780518
# DONE:  66.0
# Modin Concat Time = 3.7232494354248047
# DONE:  67.0
# Modin Concat Time = 3.680450916290283
# DONE:  68.0
# Modin Concat Time = 3.734549045562744
# DONE:  69.0
# Modin Concat Time = 3.758979082107544
# DONE:  70.0
# Modin Concat Time = 3.7656328678131104
# DONE:  71.0
# Modin Concat Time = 3.754683256149292
# DONE:  72.0
# Modin Concat Time = 3.775394916534424
# DONE:  73.0
# Modin Concat Time = 3.77199125289917
# DONE:  74.0
# Modin Concat Time = 3.7592692375183105
# DONE:  75.0
# Modin Concat Time = 3.7403318881988525
# DONE:  76.0
# Modin Concat Time = 3.7318992614746094
# DONE:  77.0
# Modin Concat Time = 3.7605433464050293
# DONE:  78.0
# Modin Concat Time = 3.706799268722534
# DONE:  79.0
# Modin Concat Time = 3.7264628410339355
# DONE:  80.0
# Modin Concat Time = 3.882071018218994
# DONE:  81.0
# Modin Concat Time = 3.7643754482269287
# DONE:  82.0
# Modin Concat Time = 3.7406668663024902
# DONE:  83.0
# Modin Concat Time = 3.7817318439483643
# DONE:  84.0
# Modin Concat Time = 3.7868714332580566
# DONE:  85.0
# Modin Concat Time = 3.799596071243286
# DONE:  86.0
# Modin Concat Time = 3.6901779174804688
# DONE:  87.0
# Modin Concat Time = 3.7488436698913574
# DONE:  88.0
# Modin Concat Time = 3.7444655895233154
# DONE:  89.0
# Modin Concat Time = 3.771121025085449
# DONE:  90.0
# Modin Concat Time = 3.7944722175598145
# DONE:  91.0
# Modin Concat Time = 3.7386786937713623
# DONE:  92.0
# Modin Concat Time = 3.800652027130127
# DONE:  93.0
# Modin Concat Time = 3.756781578063965
# DONE:  94.0
# Modin Concat Time = 3.807706117630005
# DONE:  95.0
# Modin Concat Time = 3.797117233276367
# DONE:  96.0
# Modin Concat Time = 3.794795036315918
# DONE:  97.0
# Modin Concat Time = 3.7875497341156006
# DONE:  98.0
# Modin Concat Time = 3.7497692108154297
# DONE:  99.0
# Modin Concat Time = 3.764143466949463
# DONE:  100.0
# Modin Concat Time = 3.7619595527648926
# DONE:  101.0
# Modin Concat Time = 3.7311174869537354
# DONE:  102.0
# Modin Concat Time = 3.795376777648926
# DONE:  103.0
# Modin Concat Time = 3.726776361465454
# DONE:  104.0
# Modin Concat Time = 3.7469606399536133
# DONE:  105.0
# Modin Concat Time = 3.7255125045776367
# DONE:  106.0
# Modin Concat Time = 3.7914469242095947
# DONE:  107.0
# Modin Concat Time = 3.748338222503662
# DONE:  108.0
# FuCK
# DONE:  109.0
# Modin Concat Time = 3.766878366470337
# DONE:  110.0
# Modin Concat Time = 3.75765061378479
# DONE:  111.0
# Modin Concat Time = 3.7681877613067627
# DONE:  112.0
# Modin Concat Time = 3.6719653606414795
# DONE:  113.0
# Modin Concat Time = 3.7296223640441895
# DONE:  114.0
# Modin Concat Time = 3.7412912845611572
# DONE:  115.0
# Modin Concat Time = 3.7891886234283447
# DONE:  116.0
# Modin Concat Time = 3.709890604019165
# DONE:  117.0
# Modin Concat Time = 3.7431044578552246
# DONE:  118.0
# Modin Concat Time = 3.7279348373413086
# DONE:  119.0
# Modin Concat Time = 3.7763853073120117
# DONE:  120.0
# Modin Concat Time = 3.7192931175231934
# DONE:  121.0
# Modin Concat Time = 3.7128050327301025
# DONE:  122.0
# Modin Concat Time = 3.7081449031829834
# DONE:  123.0
# Modin Concat Time = 3.8229012489318848
# DONE:  124.0
# Modin Concat Time = 3.737248659133911
# DONE:  125.0
# Modin Concat Time = 3.7291221618652344
# DONE:  126.0
# Modin Concat Time = 3.752284049987793
# DONE:  127.0
# Modin Concat Time = 3.733482599258423
# DONE:  128.0
# Modin Concat Time = 3.7912473678588867
# DONE:  129.0
# Modin Concat Time = 3.7336435317993164
# DONE:  130.0
# Modin Concat Time = 3.7404329776763916
# DONE:  131.0
# Modin Concat Time = 3.7774741649627686
# DONE:  132.0
# Modin Concat Time = 3.7567641735076904
# DONE:  133.0
# Modin Concat Time = 3.739959955215454
# DONE:  134.0
# Modin Concat Time = 3.7975189685821533
# DONE:  135.0
# Modin Concat Time = 3.7279751300811768
# DONE:  136.0
# Modin Concat Time = 3.7299633026123047
# DONE:  137.0
# Modin Concat Time = 3.713697671890259
# DONE:  138.0
# Modin Concat Time = 4.3297154903411865
# DONE:  139.0
# Modin Concat Time = 4.200080871582031
# DONE:  140.0
# Modin Concat Time = 4.054204940795898
# DONE:  141.0
# Modin Concat Time = 4.037461757659912
# DONE:  142.0
# Modin Concat Time = 3.7413699626922607
# DONE:  143.0
# Modin Concat Time = 3.743624210357666
# DONE:  144.0
# Modin Concat Time = 3.7327353954315186
# DONE:  145.0
# Modin Concat Time = 3.7212073802948
# DONE:  146.0
# Modin Concat Time = 3.7368359565734863
# DONE:  147.0
# Modin Concat Time = 3.679945707321167
# DONE:  148.0
# Modin Concat Time = 3.6637372970581055
# DONE:  149.0
# Modin Concat Time = 3.7053592205047607
# DONE:  150.0
# Modin Concat Time = 3.7071754932403564
# DONE:  151.0
# Modin Concat Time = 3.704712390899658
# DONE:  152.0
# Modin Concat Time = 3.7022833824157715
# DONE:  153.0
# Modin Concat Time = 3.739414691925049
# DONE:  154.0
# Modin Concat Time = 3.7343878746032715
# DONE:  155.0
# Modin Concat Time = 3.7470884323120117
# DONE:  156.0
# Modin Concat Time = 3.734105348587036
# DONE:  157.0
# Modin Concat Time = 3.7358410358428955
# DONE:  158.0
# Modin Concat Time = 3.6948704719543457
# DONE:  159.0
# Modin Concat Time = 3.719794511795044
# DONE:  160.0
# Modin Concat Time = 3.8394572734832764
# DONE:  161.0
# Modin Concat Time = 3.7746055126190186
# DONE:  162.0
# Modin Concat Time = 3.689338445663452
# DONE:  163.0
# Modin Concat Time = 3.710585117340088
# DONE:  164.0
# Modin Concat Time = 3.7116360664367676
# DONE:  165.0
# Modin Concat Time = 3.72944712638855
# DONE:  166.0
# Modin Concat Time = 3.777188301086426
# DONE:  167.0
# Modin Concat Time = 3.7053825855255127
# DONE:  168.0
# Modin Concat Time = 3.948660373687744
# DONE:  169.0
# Modin Concat Time = 3.762305498123169
# DONE:  170.0
# Modin Concat Time = 3.786381959915161
# DONE:  171.0
# Modin Concat Time = 3.742370367050171
# DONE:  172.0
# Modin Concat Time = 3.7123501300811768
# DONE:  173.0
# Modin Concat Time = 3.743145227432251
# DONE:  174.0
# Modin Concat Time = 3.7432379722595215
# DONE:  175.0
# Modin Concat Time = 3.717179536819458
# DONE:  176.0
# Modin Concat Time = 3.688553810119629
# DONE:  177.0
# Modin Concat Time = 3.709763288497925
# DONE:  178.0
# Modin Concat Time = 3.7187516689300537
# DONE:  179.0
# Modin Concat Time = 3.831705331802368
# DONE:  180.0
# Modin Concat Time = 3.715714454650879
# DONE:  181.0
# Modin Concat Time = 3.6967668533325195
# DONE:  182.0
# Modin Concat Time = 3.7125794887542725
# DONE:  183.0
# Modin Concat Time = 3.8659512996673584
# DONE:  184.0
# Modin Concat Time = 3.7465832233428955
# DONE:  185.0
# Modin Concat Time = 3.7351529598236084
# DONE:  186.0
# Modin Concat Time = 3.7365407943725586
# DONE:  187.0
# Modin Concat Time = 3.7797255516052246
# DONE:  188.0
# Modin Concat Time = 3.710984945297241
# DONE:  189.0
# Modin Concat Time = 3.7032663822174072
# DONE:  190.0
# Modin Concat Time = 3.7032954692840576
# DONE:  191.0
# Modin Concat Time = 3.760530471801758
# DONE:  192.0
# Modin Concat Time = 3.732201099395752
# DONE:  193.0
# Modin Concat Time = 3.700427293777466
# DONE:  194.0
# Modin Concat Time = 3.747795343399048
# DONE:  195.0
# Modin Concat Time = 3.73325514793396
# DONE:  196.0
# Modin Concat Time = 3.7233476638793945
# DONE:  197.0
# Modin Concat Time = 3.7244222164154053
# DONE:  198.0
# Modin Concat Time = 3.7828445434570312
# DONE:  199.0
# Modin Concat Time = 3.7528069019317627
# DONE:  200.0
# Modin Concat Time = 3.758357286453247
# DONE:  201.0
# Modin Concat Time = 3.8347527980804443
# DONE:  202.0
# Modin Concat Time = 3.791196584701538
# DONE:  203.0
# Modin Concat Time = 3.8182642459869385
# DONE:  204.0
# Modin Concat Time = 3.7901782989501953
# DONE:  205.0
# Modin Concat Time = 3.761988639831543
# DONE:  206.0
# Modin Concat Time = 3.9414656162261963
# DONE:  207.0
# Modin Concat Time = 3.738403797149658
# DONE:  208.0
# Modin Concat Time = 3.7563438415527344
# DONE:  209.0
# Modin Concat Time = 3.777353525161743
# DONE:  210.0
# Modin Concat Time = 3.723381757736206
# DONE:  211.0
# Modin Concat Time = 3.7433958053588867
# DONE:  212.0
# Modin Concat Time = 3.6736550331115723
# DONE:  213.0
# Modin Concat Time = 3.7427995204925537
# DONE:  214.0
# Modin Concat Time = 3.745962381362915
# DONE:  215.0
# Modin Concat Time = 4.168780565261841
# DONE:  216.0
# Modin Concat Time = 3.9576785564422607
# DONE:  217.0
# Modin Concat Time = 3.8191328048706055
# DONE:  218.0
# Modin Concat Time = 3.71915340423584
# DONE:  219.0
# Modin Concat Time = 3.722905397415161
# DONE:  220.0
# Modin Concat Time = 3.7220237255096436
# DONE:  221.0
# Modin Concat Time = 3.765726327896118
# DONE:  222.0
# Modin Concat Time = 3.6985111236572266
# DONE:  223.0
# Modin Concat Time = 3.765428304672241
# DONE:  224.0
# Modin Concat Time = 3.722597599029541
# DONE:  225.0
# Modin Concat Time = 3.7970333099365234
# DONE:  226.0
# Modin Concat Time = 3.740705728530884
# DONE:  227.0
# Modin Concat Time = 3.7670674324035645
# DONE:  228.0
# Modin Concat Time = 3.7360551357269287
# DONE:  229.0
# Modin Concat Time = 3.7814791202545166
# DONE:  230.0
# Modin Concat Time = 3.7519140243530273
# DONE:  231.0
# Modin Concat Time = 3.73582124710083
# DONE:  232.0
# Modin Concat Time = 3.737610340118408
# DONE:  233.0
# Modin Concat Time = 3.7791574001312256
# DONE:  234.0
# Modin Concat Time = 3.782127618789673
# DONE:  235.0
# Modin Concat Time = 3.705758571624756
# DONE:  236.0
# Modin Concat Time = 3.7356061935424805
# DONE:  237.0
# Modin Concat Time = 3.6912612915039062
# DONE:  238.0
# Modin Concat Time = 3.738086223602295
# DONE:  239.0
# Modin Concat Time = 3.746040105819702
# DONE:  240.0
# Modin Concat Time = 3.777531623840332
# DONE:  241.0
# Modin Concat Time = 3.8818845748901367
# DONE:  242.0
# Modin Concat Time = 3.675875663757324
# DONE:  243.0
# Modin Concat Time = 4.171117067337036
# DONE:  244.0
# Modin Concat Time = 4.072704315185547
# DONE:  245.0
# Modin Concat Time = 3.942802667617798
# DONE:  246.0
# Modin Concat Time = 3.9639596939086914
# DONE:  247.0
# Modin Concat Time = 3.86661958694458
# DONE:  248.0
# Modin Concat Time = 3.8263838291168213
# DONE:  249.0
# Modin Concat Time = 3.838123321533203
# DONE:  250.0
# Modin Concat Time = 3.8704209327697754
# DONE:  251.0

# %%
import pandas as pd
import os
files = os.listdir('trends5days')
mog = []
files.pop(0)
for x in files[:2]:
    df = pd.read_csv('trends5days/'+ x)
    mog.append(df)
dfg = pd.DataFrame(mog[0])
df1 = dfg[['Open0', 'High0', 'Low0', 'Close0', 'Adjusted_close0', 'Volume0', 'rsi0', 'ema0', 'Open1', 'High1', 'Low1', 'Close1', 'Adjusted_close1', 'Volume1', 'rsi1', 'ema1', 'Open2', 'High2', 'Low2', 'Close2', 'Adjusted_close2', 'Volume2', 'rsi2', 'ema2', 'Open3', 'High3', 'Low3', 'Close3', 'Adjusted_close3', 'Volume3', 'rsi3', 'ema3', 'Open4', 'High4', 'Low4', 'Close4', 'Adjusted_close4', 'Volume4', 'rsi4', 'ema4', 'Open5', 'High5', 'Low5', 'Close5', 'Adjusted_close5', 'Volume5', 'rsi5', 'ema5', 'Open6', 'High6', 'Low6', 'Close6', 'Adjusted_close6', 'Volume6', 'rsi6', 'ema6', 'Open7', 'High7', 'Low7', 'Close7', 'Adjusted_close7', 'Volume7', 'rsi7', 'ema7', 'Open8', 'High8', 'Low8', 'Close8', 'Adjusted_close8', 'Volume8', 'rsi8', 'ema8', 'Open9', 'High9', 'Low9', 'Close9', 'Adjusted_close9', 'Volume9', 'rsi9', 'ema9', 'Open10', 'High10', 'Low10', 'Close10', 'Adjusted_close10', 'Volume10', 'rsi10', 'ema10', 'Open11', 'High11', 'Low11', 'Close11', 'Adjusted_close11', 'Volume11', 'rsi11', 'ema11', 'Open12', 'High12', 'Low12', 'Close12', 'Adjusted_close12', 'Volume12', 'rsi12', 'ema12', 'Open13', 'High13', 'Low13', 'Close13', 'Adjusted_close13', 'Volume13', 'rsi13', 'ema13', 'Open14', 'High14', 'Low14', 'Close14', 'Adjusted_close14', 'Volume14', 'rsi14', 'ema14', 'Open15', 'High15', 'Low15', 'Close15', 'Adjusted_close15', 'Volume15', 'rsi15', 'ema15', 'Open16', 'High16', 'Low16', 'Close16', 'Adjusted_close16', 'Volume16', 'rsi16', 'ema16', 'Open17', 'High17', 'Low17', 'Close17', 'Adjusted_close17', 'Volume17', 'rsi17', 'ema17', 'Open18', 'High18', 'Low18', 'Close18', 'Adjusted_close18', 'Volume18', 'rsi18', 'ema18', 'Open19', 'High19', 'Low19', 'Close19', 'Adjusted_close19', 'Volume19', 'rsi19', 'ema19']]

dates = dfg['Date'].to_numpy()
datee = '2004-01-02'
if datee not in dates:
    print('FUCK')
else:
    print('shit')
dfg.head()
# Out:
# shit
#    Unnamed: 0        Date     Open     High      Low    Close  Adjusted_close  \
# 0           0  2004-01-02  11.8106  11.9536  11.6086  11.6708             0.0
# 1           1  2004-01-05  11.7795  12.0841  11.7330  12.0531             0.0
# 2           2  2004-01-06  12.0904  12.2582  11.8448  11.9629             0.0
# 3           3  2004-01-07  11.8728  11.9101  11.7330  11.8728             0.0
# 4           4  2004-01-08  12.1215  12.1836  11.9039  12.0157             0.0
#
#        Volume  rsi  ema  ...  rsi18  ema18  Open19  High19  Low19  Close19  \
# 0  1722766.67  NaN  NaN  ...    NaN    NaN     NaN     NaN    NaN      NaN
# 1  2812133.33  NaN  NaN  ...    NaN    NaN     NaN     NaN    NaN      NaN
# 2  2140400.00  NaN  NaN  ...    NaN    NaN     NaN     NaN    NaN      NaN
# 3  2317899.67  NaN  NaN  ...    NaN    NaN     NaN     NaN    NaN      NaN
# 4  2637766.33  NaN  NaN  ...    NaN    NaN     NaN     NaN    NaN      NaN
#
#    Adjusted_close19  Volume19  rsi19  ema19
# 0               NaN       NaN    NaN    NaN
# 1               NaN       NaN    NaN    NaN
# 2               NaN       NaN    NaN    NaN
# 3               NaN       NaN    NaN    NaN
# 4               NaN       NaN    NaN    NaN
#
# [5 rows x 171 columns]

# %%
print(mog)
# Out:
# ---------------------------------------------------------------------------
# RayTaskError(AccessDenied)                Traceback (most recent call last)
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\ray\pandas_on_ray\frame\partition.py in get(self)
#      45         try:
# ---> 46             return ray.get(self.oid)
#      47         except RayTaskError as e:
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\ray\worker.py in get(object_refs, timeout)
#    1378                 if isinstance(value, RayTaskError):
# -> 1379                     raise value.as_instanceof_cause()
#    1380                 else:
#
# RayTaskError(AccessDenied): ray::deploy_ray_func() (pid=2464, ip=192.168.1.61)
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\_pswindows.py", line 780, in cmdline
#     ret = cext.proc_cmdline(self.pid, use_peb=True)
# PermissionError: [WinError 5] Access is denied: '(originated from OpenProcess)'
#
# During handling of the above exception, another exception occurred:
#
# ray::deploy_ray_func() (pid=2464, ip=192.168.1.61)
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\_pswindows.py", line 679, in wrapper
#     return fun(self, *args, **kwargs)
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\_pswindows.py", line 695, in wrapper
#     return fun(self, *args, **kwargs)
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\_pswindows.py", line 783, in cmdline
#     ret = cext.proc_cmdline(self.pid, use_peb=False)
# PermissionError: [WinError 5] Access is denied: '(originated from OpenProcess)'
#
# During handling of the above exception, another exception occurred:
#
# ray::deploy_ray_func() (pid=2464, ip=192.168.1.61)
#   File "python\ray\_raylet.pyx", line 423, in ray._raylet.execute_task
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\memory_monitor.py", line 131, in raise_if_low_memory
#     RayOutOfMemoryError.get_message(used_gb, total_gb,
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\memory_monitor.py", line 43, in get_message
#     proc.cmdline()))
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\__init__.py", line 677, in cmdline
#     return self._proc.cmdline()
#   File "C:\Users\tosze\Anaconda3\envs\Sentiment\lib\site-packages\ray\thirdparty_files\psutil\_pswindows.py", line 681, in wrapper
#     raise convert_oserror(err, pid=self.pid, name=self._name)
# psutil.AccessDenied: psutil.AccessDenied (pid=56)
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-5833aebdf7a6> in <module>
# ----> 1 print(mog)
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\pandas\dataframe.py in __repr__(self)
#     182
#     183             num_cols += len(self.columns) - i
# --> 184         result = repr(self._build_repr_df(num_rows, num_cols))
#     185         if len(self.index) > num_rows or len(self.columns) > num_cols:
#     186             # The split here is so that we don't repr pandas row lengths.
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\pandas\base.py in _build_repr_df(self, num_rows, num_cols)
#     196         else:
#     197             indexer = row_indexer
# --> 198         return self.iloc[indexer]._query_compiler.to_pandas()
#     199
#     200     def _update_inplace(self, new_query_compiler):
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\backends\pandas\query_compiler.py in to_pandas(self)
#     206
#     207     def to_pandas(self):
# --> 208         return self._modin_frame.to_pandas()
#     209
#     210     @classmethod
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\base\frame\data.py in to_pandas(self)
#    2081             Pandas DataFrame.
#    2082         """
# -> 2083         df = self._frame_mgr_cls.to_pandas(self._partitions)
#    2084         if df.empty:
#    2085             if len(self.columns) != 0:
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\base\frame\partition_manager.py in to_pandas(cls, partitions)
#     571             A Pandas DataFrame
#     572         """
# --> 573         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     574         if all(
#     575             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\base\frame\partition_manager.py in <listcomp>(.0)
#     571             A Pandas DataFrame
#     572         """
# --> 573         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     574         if all(
#     575             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\base\frame\partition_manager.py in <listcomp>(.0)
#     571             A Pandas DataFrame
#     572         """
# --> 573         retrieved_objects = [[obj.to_pandas() for obj in part] for part in partitions]
#     574         if all(
#     575             isinstance(part, pandas.Series) for row in retrieved_objects for part in row
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\ray\pandas_on_ray\frame\partition.py in to_pandas(self)
#     106             A Pandas DataFrame.
#     107         """
# --> 108         dataframe = self.get()
#     109         assert type(dataframe) is pandas.DataFrame or type(dataframe) is pandas.Series
#     110         return dataframe
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\ray\pandas_on_ray\frame\partition.py in get(self)
#      46             return ray.get(self.oid)
#      47         except RayTaskError as e:
# ---> 48             handle_ray_task_error(e)
#      49
#      50     def apply(self, func, **kwargs):
#
# ~\Anaconda3\envs\Sentiment\lib\site-packages\modin\engines\ray\utils.py in handle_ray_task_error(e)
#      31         if "Error" in s or "Exception" in s:
#      32             try:
# ---> 33                 raise getattr(builtins, s.split(":")[0])("".join(s.split(":")[1:]))
#      34             except AttributeError as att_err:
#      35                 if "module" in str(att_err) and builtins.__name__ in str(att_err):
#
# PermissionError:  [WinError 5] Access is denied '(originated from OpenProcess)'

# %%
import modin.pandas as pd
import os
files = os.listdir('trends5days')
for x in

# %%
import numpy as np
x = np.array([5,6,7,3,5,6,2,5,63,4])
pos = np.where(x==63)
print(pos[0][0]+2)
# Out:
# 10
