# %%
import pandas as pd
import os 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle
import warnings
warnings.filterwarnings('ignore')
xddd = 0
files = os.listdir('trends5days')
files.pop(0)
poprawnosc = []
for x in files:
    print(x)
    number = files.index(x)
    company3 = pd.read_csv('trends5days/'+x)
    lenght = len(company3)
 
    
    #company1 = company3.tail(1500)
    #company2 = company3.head(1000)
    company = company3.head(3000)
    company.reset_index(drop=True, inplace=True)

    
    
    print('__________________________________')
    df = company3[['Date','Open','High','Low','Close','Adjusted_close','Volume','rsi','ema','change']]
    
    from sklearn.preprocessing import MinMaxScaler
   # sc= MinMaxScaler(feature_range=(0,1))
   # df['Open0']=sc.fit_transform(df['Open'].to_numpy().reshape(-1, 1))
   # df['High0']=sc.fit_transform(df['High'].to_numpy().reshape(-1, 1))
   # df['Low0']=sc.fit_transform(df['Low'].to_numpy().reshape(-1, 1))
    #df['Close0']=sc.fit_transform(df['Close'].to_numpy().reshape(-1, 1))
    #df['Adjusted_close0']=sc.fit_transform(df['Adjusted_close'].to_numpy().reshape(-1, 1))
    #df['Volume0']=sc.fit_transform(df['Volume'].to_numpy().reshape(-1, 1))
    #df['rsi0']=sc.fit_transform(df['rsi'].to_numpy().reshape(-1, 1))
    #df['ema0']=sc.fit_transform(df['ema'].to_numpy().reshape(-1, 1))
#
    #
    #for i in range(1,20):
    #    df['Open'+str(i)] = df['Open0'].shift(i)
    #    df['High'+str(i)] = df['High0'].shift(i)
    #    df['Low'+str(i)] = df['Low0'].shift(i)
    #    df['Close'+str(i)] = df['Close0'].shift(i)
    #    df['Adjusted_close'+str(i)] = df['Adjusted_close0'].shift(i)
    #    df['Volume'+str(i)] = df['Volume0'].shift(i)
    #    df['rsi'+str(i)] = df['rsi0'].shift(i)
    #    df['ema'+str(i)] = df['ema0'].shift(i)
    #
    #df.to_csv('trends5days/'+x)
    company.dropna(inplace=True)
    my_list = list(df)
    X = company[['Open0', 'High0', 'Low0', 'Close0', 'Adjusted_close0', 'Volume0','rsi0', 'ema0', 'Open1', 'High1', 'Low1', 'Close1', 'Adjusted_close1', 'Volume1', 'rsi1', 'ema1', 'Open2', 'High2', 'Low2', 'Close2', 'Adjusted_close2', 'Volume2', 'rsi2', 'ema2', 'Open3', 'High3', 'Low3', 'Close3', 'Adjusted_close3', 'Volume3', 'rsi3', 'ema3', 'Open4', 'High4', 'Low4', 'Close4', 'Adjusted_close4', 'Volume4', 'rsi4', 'ema4', 'Open5', 'High5', 'Low5', 'Close5', 'Adjusted_close5', 'Volume5', 'rsi5', 'ema5', 'Open6', 'High6', 'Low6', 'Close6', 'Adjusted_close6', 'Volume6', 'rsi6', 'ema6', 'Open7', 'High7', 'Low7', 'Close7', 'Adjusted_close7', 'Volume7', 'rsi7', 'ema7', 'Open8', 'High8', 'Low8', 'Close8', 'Adjusted_close8', 'Volume8', 'rsi8', 'ema8', 'Open9', 'High9', 'Low9', 'Close9', 'Adjusted_close9', 'Volume9', 'rsi9', 'ema9', 'Open10', 'High10', 'Low10', 'Close10', 'Adjusted_close10', 'Volume10', 'rsi10', 'ema10', 'Open11', 'High11', 'Low11', 'Close11', 'Adjusted_close11', 'Volume11', 'rsi11', 'ema11', 'Open12', 'High12', 'Low12', 'Close12', 'Adjusted_close12', 'Volume12', 'rsi12', 'ema12', 'Open13', 'High13', 'Low13', 'Close13', 'Adjusted_close13', 'Volume13', 'rsi13', 'ema13', 'Open14', 'High14', 'Low14', 'Close14', 'Adjusted_close14', 'Volume14', 'rsi14', 'ema14', 'Open15', 'High15', 'Low15', 'Close15', 'Adjusted_close15', 'Volume15', 'rsi15', 'ema15', 'Open16', 'High16', 'Low16', 'Close16', 'Adjusted_close16', 'Volume16', 'rsi16', 'ema16', 'Open17', 'High17', 'Low17', 'Close17', 'Adjusted_close17', 'Volume17', 'rsi17', 'ema17', 'Open18', 'High18', 'Low18', 'Close18', 'Adjusted_close18', 'Volume18', 'rsi18', 'ema18', 'Open19', 'High19', 'Low19', 'Close19', 'Adjusted_close19', 'Volume19', 'rsi19', 'ema19']].values
    y = []
    y = company['change'].to_list()
    X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.33, random_state=42)
    
    param_grid = { 
        'n_estimators': [500, 700, 1000], 'max_depth': [None, 1, 2, 3], 'min_samples_split': [1, 2, 3]
    }
    from sklearn.ensemble import AdaBoostClassifier
    from sklearn.tree import DecisionTreeClassifier
    adb = AdaBoostClassifier(DecisionTreeClassifier(min_samples_split=10,max_depth=4),n_estimators=10,learning_rate=0.6)
    adb.fit(X_train, y_train)
    print("score on test: " + str(adb.score(X_test, y_test)))
    print("score on train: "+ str(adb.score(X_train, y_train)))
    poprawnosc.append(adb.score(X_test, y_test))
    vvb = adb.predict_proba(X_test)
    vb = adb.predict(X_test)
    score=0
    list1 = []
    list2 = []
    #for h in range(len(vvb)):
        #if vvb[h][1] > 0.98:
            #list1.append(y_test[h])
            #list2.append(vb[h])
    
    #for j in range(len(list1)):
        #if list1[j] == list2[j]:
            #score+=1
    #print(score/len(list1))
    g = x[:-4]
    filename = 'trends5daysModelCorrect/'+g +'.sav'
    pickle.dump(adb, open(filename, 'wb'))
    print('SAVED')
    


print("LIIDJJDJDDJ:     ",xddd)
# Out:
# AATRENDS.csv
# __________________________________
# score on test: 0.8274793388429752
# score on train: 0.935336048879837
# SAVED
# ABCBTRENDS.csv
# __________________________________
# score on test: 0.6384297520661157
# score on train: 0.8309572301425662
# SAVED
# ABCTRENDS.csv
# __________________________________
# score on test: 0.6074380165289256
# score on train: 0.820264765784114
# SAVED
# ABEOTRENDS.csv
# __________________________________
# score on test: 0.9070247933884298
# score on train: 0.9765784114052953
# SAVED
# ABGTRENDS.csv
# __________________________________
# score on test: 0.6002066115702479
# score on train: 0.8212830957230143
# SAVED
# ABMDTRENDS.csv
# __________________________________
# score on test: 0.6177685950413223
# score on train: 0.825356415478615
# SAVED
# ABMTRENDS.csv
# __________________________________
# score on test: 0.6146694214876033
# score on train: 0.8243380855397149
# SAVED
# ABTTRENDS.csv
# __________________________________
# ...

# %%
print(poprawnosc)
# Out:
# [0.577524893314367, 0.7815420560747663, 0.5960170697012802, 0.5924608819345661, 0.5945945945945946, 0.596728307254623, 0.60099573257468, 0.5924608819345661, 0.6130867709815079, 0.5974395448079659, 0.5832147937411095, 0.5604551920341394, 0.5668563300142248, 0.5768136557610242, 0.585348506401138, 0.5722419928825623, 0.6756756756756757, 0.5554765291607396, 0.6180654338549075, 0.5953058321479374, 0.616642958748222, 0.5704125177809388, 0.585348506401138, 0.5796586059743954, 0.6792318634423897, 0.5846372688477952, 0.5874822190611664, 0.6130867709815079, 0.5817923186344239]

# %%
import pandas as pd
df = pd.read_csv('trends5days/WHRTRENDS.csv')
df.head(1000)
# Out:
#      Unnamed: 0        Date   Open   High    Low  Close  Adjusted_close  \
# 0             0  2004-01-02  72.88  73.15  70.98  71.18             0.0
# 1             1  2004-01-05  72.25  72.45  71.15  72.22             0.0
# 2             2  2004-01-06  72.00  72.43  71.45  71.90             0.0
# 3             3  2004-01-07  71.91  72.52  71.55  72.23             0.0
# 4             4  2004-01-08  72.24  73.23  71.35  72.78             0.0
# ..          ...         ...    ...    ...    ...    ...             ...
# 995         995  2007-12-14  82.91  82.91  80.13  81.29             0.0
# 996         996  2007-12-17  80.78  82.38  79.77  80.42             0.0
# 997         997  2007-12-18  81.09  82.39  78.75  81.47             0.0
# 998         998  2007-12-19  81.65  81.65  80.06  80.61             0.0
# 999         999  2007-12-20  81.36  81.70  79.89  81.55             0.0
#
#         Volume        rsi      ema  ...     rsi18     ema18    Open19  \
# ...

# %%
# Out:
# 527
# ['WELLTRENDS.csv', 'WENTRENDS.csv', 'WFCTRENDS.csv', 'WHRTRENDS.csv', 'WLTWTRENDS.csv', 'WMBTRENDS.csv', 'WMTRENDS.csv', 'WMTTRENDS.csv', 'WRBTRENDS.csv', 'WRITRENDS.csv', 'WSFSTRENDS.csv', 'WSMTRENDS.csv', 'WSOTRENDS.csv', 'WSTTRENDS.csv', 'WTFCTRENDS.csv', 'WTMTRENDS.csv', 'WWETRENDS.csv', 'WYNNTRENDS.csv', 'WYTRENDS.csv', 'XECTRENDS.csv', 'XELTRENDS.csv', 'XLNXTRENDS.csv', 'XOMTRENDS.csv', 'XRAYTRENDS.csv', 'XRXTRENDS.csv', 'YUMTRENDS.csv', 'ZBHTRENDS.csv', 'ZBRATRENDS.csv', 'ZIONTRENDS.csv']

# %%
pritn("KUREQAAAAAAAAAAAAAAAAAAAAAA")
    df.dropna(inplace=True)
    my_list = list(df)
    X = df[['Open0', 'High0', 'Low0', 'Close0', 'Adjusted_close0', 'Volume0','rsi0', 'ema0', 'Open1', 'High1', 'Low1', 'Close1', 'Adjusted_close1', 'Volume1', 'rsi1', 'ema1', 'Open2', 'High2', 'Low2', 'Close2', 'Adjusted_close2', 'Volume2', 'rsi2', 'ema2', 'Open3', 'High3', 'Low3', 'Close3', 'Adjusted_close3', 'Volume3', 'rsi3', 'ema3', 'Open4', 'High4', 'Low4', 'Close4', 'Adjusted_close4', 'Volume4', 'rsi4', 'ema4', 'Open5', 'High5', 'Low5', 'Close5', 'Adjusted_close5', 'Volume5', 'rsi5', 'ema5', 'Open6', 'High6', 'Low6', 'Close6', 'Adjusted_close6', 'Volume6', 'rsi6', 'ema6', 'Open7', 'High7', 'Low7', 'Close7', 'Adjusted_close7', 'Volume7', 'rsi7', 'ema7', 'Open8', 'High8', 'Low8', 'Close8', 'Adjusted_close8', 'Volume8', 'rsi8', 'ema8', 'Open9', 'High9', 'Low9', 'Close9', 'Adjusted_close9', 'Volume9', 'rsi9', 'ema9', 'Open10', 'High10', 'Low10', 'Close10', 'Adjusted_close10', 'Volume10', 'rsi10', 'ema10', 'Open11', 'High11', 'Low11', 'Close11', 'Adjusted_close11', 'Volume11', 'rsi11', 'ema11', 'Open12', 'High12', 'Low12', 'Close12', 'Adjusted_close12', 'Volume12', 'rsi12', 'ema12', 'Open13', 'High13', 'Low13', 'Close13', 'Adjusted_close13', 'Volume13', 'rsi13', 'ema13', 'Open14', 'High14', 'Low14', 'Close14', 'Adjusted_close14', 'Volume14', 'rsi14', 'ema14', 'Open15', 'High15', 'Low15', 'Close15', 'Adjusted_close15', 'Volume15', 'rsi15', 'ema15', 'Open16', 'High16', 'Low16', 'Close16', 'Adjusted_close16', 'Volume16', 'rsi16', 'ema16', 'Open17', 'High17', 'Low17', 'Close17', 'Adjusted_close17', 'Volume17', 'rsi17', 'ema17', 'Open18', 'High18', 'Low18', 'Close18', 'Adjusted_close18', 'Volume18', 'rsi18', 'ema18', 'Open19', 'High19', 'Low19', 'Close19', 'Adjusted_close19', 'Volume19', 'rsi19', 'ema19']].values
    #y = df['change'].values
    y = []
    var = df['change'].to_list()
    #for x in var:
    #    if x == 1:
    #        y.append(1)
    #    elif x == 0:
    #        y.append(0)
    #    else:
    #        y.append(0)
    y = df['change'].to_list()
    X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.33, random_state=42)
    
    param_grid = { 
        'n_estimators': [500, 700, 1000], 'max_depth': [None, 1, 2, 3], 'min_samples_split': [1, 2, 3]
    }
    from sklearn.ensemble import AdaBoostClassifier
    from sklearn.tree import DecisionTreeClassifier
    adb = AdaBoostClassifier(DecisionTreeClassifier(min_samples_split=10,max_depth=4),n_estimators=10,learning_rate=0.6)
    adb.fit(X_train, y_train)
    print("score on test: " + str(adb.score(X_test, y_test)))
    print("score on train: "+ str(adb.score(X_train, y_train)))
    vvb = adb.predict_proba(X_test)
    vb = adb.predict(X_test)
    score=0
    list1 = []
    list2 = []
    for h in range(len(vvb)):
        if vvb[h][1] > 0.98:
            list1.append(y_test[h])
            list2.append(vb[h])
    
    for j in range(len(list1)):
        if list1[j] == list2[j]:
            score+=1
    #print(score/len(list1))
    g = x[:-4]
    filename = 'MaxhineLearning5per/'+g +'.sav'
    pickle.dump(adb, open(filename, 'wb'))
    df.to_csv('Trends5per-ML/'+x)
    print('SAVED')

# %%
import pandas as pd
df = pd.read_csv('Trends5per-ML/AAPLTRENDS.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-fb416773e80a> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('Trends5per-ML/AAPLTRENDS.csv')
#       3 df.head()
#
# ...

# %%
x = 'hhhhhh.csv'
print(x[:-3])
# Out:
# hhhhhh.

# %%
print(X_test[1])
xdd = df['High'].to_list()
xdd.index(0.0648835)
# Out:
# [0.0648835  0.06303813 0.0626911  0.06409438 0.02020202 0.02935074
#  0.41131127 0.02270721 0.06311277 0.06249548 0.06081094 0.06460157
#  0.03030303 0.06678639 0.42045417 0.02376339 0.06247903 0.06164532
#  0.05811414 0.06366232 0.03030303 0.06397851 0.40321331 0.02491631
#  0.05586207 0.06166341 0.05632893 0.06386896 0.03030303 0.08758613
#  0.40647768 0.02605154 0.05548928 0.05627306 0.05469566 0.05539693
#  0.03030303 0.03422852 0.23801524 0.02710282 0.05211556 0.05692425
#  0.04987181 0.05740692 0.03030303 0.06584762 0.26468257 0.02846196
#  0.05280522 0.05243832 0.05087836 0.05156479 0.03030303 0.03662207
#  0.1183641  0.02973714 0.05032619 0.05415672 0.05082157 0.05357478
#  0.03030303 0.06442954 0.13998093 0.03107222 0.04721342 0.05017727
#  0.04741715 0.04895368 0.03030303 0.0676551  0.00351917 0.03245346
#  0.05256291 0.05173287 0.04751685 0.04884097 0.03030303 0.08643673
#  0.         0.03409297 0.05459459 0.05516967 0.05347678 0.05592291
# ...

# %%
x = 0
if x > 0:
    print('ez')
else:
    print('not ez')
# Out:
# not ez

# %%
x = 20
print(str(x))
# Out:
# 20

# %%
import pandas as pd
import os 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle

files = os.listdir('Trends-GooglTrends')
files.pop(0)
print(files)
for x in files:
    print(x)
    number = files.index(x)
    company = pd.read_csv('Trends-GooglTrends/'+x)
    company.head()
    df = company[['Open','High','Low','Close','Adjusted_close','Volume','rsi','ema','change']]
    
    from sklearn.preprocessing import MinMaxScaler
    sc= MinMaxScaler(feature_range=(0,1))
    df['Open']=sc.fit_transform(df['Open'].to_numpy().reshape(-1, 1))
    df['High']=sc.fit_transform(df['High'].to_numpy().reshape(-1, 1))
    df['Low']=sc.fit_transform(df['Low'].to_numpy().reshape(-1, 1))
    df['Close']=sc.fit_transform(df['Close'].to_numpy().reshape(-1, 1))
    df['Adjusted_close']=sc.fit_transform(df['Adjusted_close'].to_numpy().reshape(-1, 1))
    df['Volume']=sc.fit_transform(df['Volume'].to_numpy().reshape(-1, 1))
    df['rsi']=sc.fit_transform(df['rsi'].to_numpy().reshape(-1, 1))
    df['ema']=sc.fit_transform(df['ema'].to_numpy().reshape(-1, 1))


    for i in range(1,20):
        df['Open'+str(i)] = df['Open'].shift(i)
        df['High'+str(i)] = df['High'].shift(i)
        df['Low'+str(i)] = df['Low'].shift(i)
        df['Close'+str(i)] = df['Close'].shift(i)
        df['Adjusted_close'+str(i)] = df['Adjusted_close'].shift(i)
        df['Volume'+str(i)] = df['Volume'].shift(i)
        df['rsi'+str(i)] = df['rsi'].shift(i)
        df['ema'+str(i)] = df['ema'].shift(i)
    df.dropna(inplace=True)
    my_list = list(df)
    X = df[['Open', 'High', 'Low', 'Close', 'Adjusted_close', 'Volume', 'rsi', 'ema', 'Open1', 'High1', 'Low1', 'Close1', 'Adjusted_close1', 'Volume1', 'rsi1', 'ema1', 'Open2', 'High2', 'Low2', 'Close2', 'Adjusted_close2', 'Volume2', 'rsi2', 'ema2', 'Open3', 'High3', 'Low3', 'Close3', 'Adjusted_close3', 'Volume3', 'rsi3', 'ema3', 'Open4', 'High4', 'Low4', 'Close4', 'Adjusted_close4', 'Volume4', 'rsi4', 'ema4', 'Open5', 'High5', 'Low5', 'Close5', 'Adjusted_close5', 'Volume5', 'rsi5', 'ema5', 'Open6', 'High6', 'Low6', 'Close6', 'Adjusted_close6', 'Volume6', 'rsi6', 'ema6', 'Open7', 'High7', 'Low7', 'Close7', 'Adjusted_close7', 'Volume7', 'rsi7', 'ema7', 'Open8', 'High8', 'Low8', 'Close8', 'Adjusted_close8', 'Volume8', 'rsi8', 'ema8', 'Open9', 'High9', 'Low9', 'Close9', 'Adjusted_close9', 'Volume9', 'rsi9', 'ema9', 'Open10', 'High10', 'Low10', 'Close10', 'Adjusted_close10', 'Volume10', 'rsi10', 'ema10', 'Open11', 'High11', 'Low11', 'Close11', 'Adjusted_close11', 'Volume11', 'rsi11', 'ema11', 'Open12', 'High12', 'Low12', 'Close12', 'Adjusted_close12', 'Volume12', 'rsi12', 'ema12', 'Open13', 'High13', 'Low13', 'Close13', 'Adjusted_close13', 'Volume13', 'rsi13', 'ema13', 'Open14', 'High14', 'Low14', 'Close14', 'Adjusted_close14', 'Volume14', 'rsi14', 'ema14', 'Open15', 'High15', 'Low15', 'Close15', 'Adjusted_close15', 'Volume15', 'rsi15', 'ema15', 'Open16', 'High16', 'Low16', 'Close16', 'Adjusted_close16', 'Volume16', 'rsi16', 'ema16', 'Open17', 'High17', 'Low17', 'Close17', 'Adjusted_close17', 'Volume17', 'rsi17', 'ema17', 'Open18', 'High18', 'Low18', 'Close18', 'Adjusted_close18', 'Volume18', 'rsi18', 'ema18', 'Open19', 'High19', 'Low19', 'Close19', 'Adjusted_close19', 'Volume19', 'rsi19', 'ema19']].values
    #y = df['change'].values
    y = []
    var = df['change'].to_list()
    for x in var:
        if x > 0:
            y.append(1)
        elif x < 0:
            y.append(0)
        else:
            y.append(0)
    X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.33, random_state=42)
    
    param_grid = { 
        'n_estimators': [500, 700, 1000], 'max_depth': [None, 1, 2, 3], 'min_samples_split': [1, 2, 3]
    }
    from sklearn.ensemble import AdaBoostClassifier
    from sklearn.tree import DecisionTreeClassifier
    adb = AdaBoostClassifier(DecisionTreeClassifier(min_samples_split=10,max_depth=4),n_estimators=10,learning_rate=0.6)
    adb.fit(X_train, y_train)
    print("score on test: " + str(adb.score(X_test, y_test)))
    print("score on train: "+ str(adb.score(X_train, y_train)))
    vvb = adb.predict_proba(X_test)
    vb = adb.predict(X_test)
    filename = 'MachineLearningModels/ML'+str(number) +'.sav'
    pickle.dump(adb, open(filename, 'wb'))
    list1 = []
    list2 = []
    for x in range(len(vvb)):
        if vvb[x][1] > 0.90 or vvb[x][0] > 0.90:
            list1.append(y_test[x])
            list2.append(vb[x])

    score=0
    for x in range(len(list1)):
        if list1[x] == list2[x]:
            score+=1
    print(score/len(list1))
    print(len(list1))

# %%
import pandas as pd
import os
gg = []
def makeSet(file):
    ticker = pd.read_csv('TrendsV3_L/'+file)
    print(len(ticker))
    for x in range(len(ticker)):
        if x != len(ticker)-32:
            first_m= ticker['Close'][x]
            second_m = ticker['Close'][x+5]
            change = (first_m/second_m)*100
            if change > 100:
                change_m = change-100
            else:
                change_m = change-100
            ticker['change'][x]= change_m
            ticker.to_csv('TrendsV3_L/'+file)
        else:
            break
#df_6 = pd.read_csv('nasdaq-100.csv')
#spolki = df_6['Symbol'].to_list()
spolki = os.listdir('TrendsV3_L')
spolki.pop(0)
print(spolki)
spolki.reverse()
print(spolki)
for x in spolki:
    print('START: ',x)
    makeSet(x)
    print('DONE: ',x)
# Out:
# ['AAPLTRENDS.csv', 'ADBETRENDS.csv', 'ADITRENDS.csv', 'ADPTRENDS.csv', 'ADSKTRENDS.csv', 'AEPTRENDS.csv', 'ALGNTRENDS.csv', 'ALXNTRENDS.csv', 'AMATTRENDS.csv', 'AMDTRENDS.csv', 'AMGNTRENDS.csv', 'AMZNTRENDS.csv', 'ANSSTRENDS.csv', 'ASMLTRENDS.csv', 'ATVITRENDS.csv', 'BKNGTRENDS.csv', 'CDNSTRENDS.csv', 'CERNTRENDS.csv', 'CHKPTRENDS.csv', 'CMCSATRENDS.csv', 'COSTTRENDS.csv', 'CPRTTRENDS.csv', 'CSCOTRENDS.csv', 'CSXTRENDS.csv', 'CTASTRENDS.csv', 'CTSHTRENDS.csv', 'DLTRTRENDS.csv', 'EATRENDS.csv', 'EBAYTRENDS.csv', 'EXCTRENDS.csv', 'FASTTRENDS.csv', 'FISVTRENDS.csv', 'GILDTRENDS.csv', 'IDXXTRENDS.csv', 'ILMNTRENDS.csv', 'INCYTRENDS.csv', 'INTCTRENDS.csv', 'INTUTRENDS.csv', 'ISRGTRENDS.csv', 'KLACTRENDS.csv', 'LRCXTRENDS.csv', 'MCHPTRENDS.csv', 'MDLZTRENDS.csv', 'MRVLTRENDS.csv', 'MSFTTRENDS.csv', 'MUTRENDS.csv', 'MXIMTRENDS.csv', 'NFLXTRENDS.csv', 'NTESTRENDS.csv', 'NVDATRENDS.csv', 'ORLYTRENDS.csv', 'PAYXTRENDS.csv', 'PCARTRENDS.csv', 'PEPTRENDS.csv', 'QCOMTRENDS.csv', 'ROSTTRENDS.csv',
# ...

# %%
company = pd.read_csv('Trends-GooglTrends/'+x)

# %%
import os
import pandas as pd
files = os.listdir('Trendsup')
print(files)
files.pop(0)
for x in files:
    
    company = pd.read_csv('Trendsup/'+x)
    df = company[['Open','High','Low','Close','Adjusted_close','Volume','rsi','ema']]
    print(df.head(65))
    print(df.head(65))
    print(len(df))
    from sklearn.preprocessing import MinMaxScaler
    sc= MinMaxScaler(feature_range=(0,1))
    df['Open']=sc.fit_transform(df['Open'].to_numpy().reshape(-1, 1))
    df['High']=sc.fit_transform(df['High'].to_numpy().reshape(-1, 1))
    df['Low']=sc.fit_transform(df['Low'].to_numpy().reshape(-1, 1))
    df['Close']=sc.fit_transform(df['Close'].to_numpy().reshape(-1, 1))
    df['Adjusted_close']=sc.fit_transform(df['Adjusted_close'].to_numpy().reshape(-1, 1))
    df['Volume']=sc.fit_transform(df['Volume'].to_numpy().reshape(-1, 1))
    df['rsi']=sc.fit_transform(df['rsi'].to_numpy().reshape(-1, 1))
    df['ema']=sc.fit_transform(df['ema'].to_numpy().reshape(-1, 1))


    for i in range(1,20):
        df['Open'+str(i)] = df['Open'].shift(i)
        df['High'+str(i)] = df['High'].shift(i)
        df['Low'+str(i)] = df['Low'].shift(i)
        df['Close'+str(i)] = df['Close'].shift(i)
        df['Adjusted_close'+str(i)] = df['Adjusted_close'].shift(i)
        df['Volume'+str(i)] = df['Volume'].shift(i)
        df['rsi'+str(i)] = df['rsi'].shift(i)
        df['ema'+str(i)] = df['ema'].shift(i)
    df.dropna(inplace=True)
    print(len(df))
    df.to_csv('Trendsup-ML/'+x)
# Out:
# ['ABCTRENDS.csv', 'ABTTRENDS.csv', 'ACNTRENDS.csv', 'ADBETRENDS.csv', 'ADITRENDS.csv', 'ADMTRENDS.csv', 'ADPTRENDS.csv', 'ADSKTRENDS.csv', 'AEETRENDS.csv', 'AEPTRENDS.csv', 'AESTRENDS.csv', 'AFLTRENDS.csv', 'AIGTRENDS.csv', 'AJGTRENDS.csv', 'ALGNTRENDS.csv', 'ALLTRENDS.csv', 'ALXNTRENDS.csv', 'AMATTRENDS.csv', 'AMDTRENDS.csv', 'AMETRENDS.csv', 'AMGNTRENDS.csv', 'AMTTRENDS.csv', 'AMZNTRENDS.csv', 'ANSSTRENDS.csv', 'ANTMTRENDS.csv', 'AONTRENDS.csv', 'APDTRENDS.csv', 'APHTRENDS.csv', 'ARETRENDS.csv', 'ATRENDS.csv', 'ATVITRENDS.csv', 'AVBTRENDS.csv', 'AXPTRENDS.csv', 'AZOTRENDS.csv', 'BACTRENDS.csv', 'BATRENDS.csv', 'BAXTRENDS.csv', 'BBYTRENDS.csv', 'BDXTRENDS.csv', 'BIIBTRENDS.csv', 'BKNGTRENDS.csv', 'BKRTRENDS.csv', 'BKTRENDS.csv', 'BLKTRENDS.csv', 'BLLTRENDS.csv', 'BMYTRENDS.csv', 'BSXTRENDS.csv', 'CATTRENDS.csv', 'CBRETRENDS.csv', 'CBTRENDS.csv', 'CCITRENDS.csv', 'CCLTRENDS.csv', 'CDNSTRENDS.csv', 'CERNTRENDS.csv', 'CHDTRENDS.csv', 'CITRENDS.csv', 'CLTRENDS.csv', 'CLXTRENDS.csv', 'CM
# ...
